# %% [markdown]
# # Running NLTK in VS Code .ipynb
#
# ### 1. Install NLTK
# In VSCode Terminal, write this down:

# %%
pip install nltk

# %% [markdown]
# #### One-time Setup (Run This First)

# %%
# Download all commonly used NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# ### 2. Download Required Data

# %%
import nltk

# Download tokenizer data
# nltk.download('punkt')
# Because my python 3.13 ain't compatible, so:
nltk.download('punkt_tab')

# Download POS tagger data
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### 3. Run Your Code

# %%
from nltk.tokenize import TreebankWordTokenizer

sentence = "At eight o'clock on Thursday morning Arthur didn't feel very good."
# tokens = nltk.word_tokenize(sentence)
# because python 3.13 ain't compatible, so we command # that above.  instead, we use this:
tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize(sentence)
print(tokens)

# We command this below since python 3.13+ ain't compatible:
# tagged = nltk.pos_tag(tokens)
# print(tagged[0:6])
# Out:
# ['At', 'eight', "o'clock", 'on', 'Thursday', 'morning', 'Arthur', 'did', "n't", 'feel', 'very', 'good', '.']

# %% [markdown]
# ### If You Get LookupError
# Just run `nltk.download('punkt')` once - it downloads the tokenizer models to your machine permanently.
